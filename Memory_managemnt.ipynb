# %% [markdown]
# Memory Management in python involves a combnination of automatic garbage collection
# and various internal optimizations to effiently manage memory allocation and deallocation.Understanding
# these mechanisms can help devlopers write more efficient and robust applications

# %% [markdown]
# <li>Key concepts in Python Memory Management</li>
# <li>Memory allocation and deallocation</li>
# <li>Reference collecting</li>
# <li>Garbage Collection</li>
# <li>The gc Module</li>
# <li>Memory Management Best practices</li>

# %% [markdown]
# ### Reference Counting
#  Reference Counting is the primary method python uses to manage memory .Each object in Python maintains a count of references pointing to it .When the reference count drops to zero,the memory occupied bu the object is deallocated.

# %%
import sys
a = []

print(sys.getrefcount(a))
# Out:
# 2

# %%
b = a
print(sys.getrefcount(b))
# Out:
# 3

# %%
del b 
print(sys.getrefcount(a))
# Out:
# 2

# %% [markdown]
# ### garbage collection <div>
# python includes  a cyclic garbage collector to handle reference cycles.Reference cycles occur when objects reference each other ,preventing their refernce coutns from reaching zero

# %%
import gc ##garbage collection 

gc.enable()

# %%
gc.disable()

# %%
gc.collect()
# Out:
# 236

# %%
## get garbage collection stats 
print(gc.get_stats())
# Out:
# [{'collections': 185, 'collected': 1499, 'uncollectable': 0}, {'collections': 16, 'collected': 361, 'uncollectable': 0}, {'collections': 2, 'collected': 236, 'uncollectable': 0}]

# %%
print(gc.garbage)
# Out:
# []

# %%
import gc 
class MyObject:
    def __init__(self,name):
        self.name = name
        print(f"object {self.name} created")
    def __del__(self):
        print(f"object {self.name} deleted")
#create circular references
obj1 = MyObject("obj1")
obj2 = MyObject("obj2")
obj1.ref  = obj2
obj2.ref = obj1 
del obj1 
del obj2 
gc.collect()
# Out:
# object obj1 created
# object obj2 created
# object obj1 deleted
# object obj2 deleted
# 9
