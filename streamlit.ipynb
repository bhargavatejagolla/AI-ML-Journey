# %% [markdown]
# # Introduction to Streamlit

# %% [markdown]
# Streamlit is an open source app frame work for Machine learning and data science projects.It allows you to create beautiful web applications for machine learning and data science projects with simple python scripts

# %% [markdown]
# pip install streamlit

# %%
# Out:
# 2026-05-15 15:21:39.584 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-15 15:21:39.851
# ...
#   command:
#
#     streamlit run c:\Users\bharg\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-15 15:21:39.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
