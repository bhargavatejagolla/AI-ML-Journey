# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
df_index = pd.read_csv("economic_index.csv")
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
print(df_index.columns.tolist())
# Out:
# ['year', 'month', 'interest_rate', 'unemployment_rate', 'index_price']

# %%
df_index = df_index.drop(columns=["year", "month"])

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
### visualize the datapoints more closely
plt.scatter(df_index["interest_rate"],df_index["unemployment_rate"],color= "r")
plt.xlabel("Interest rate")
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
### independent and dependent features
X =df_index.iloc[:,:-1]
Y  = df_index.iloc[:,-1]

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
Y.head()
# Out:
# 0    1464
# 1    1394
# 2    1357
# 3    1293
# 4    1256
# Name: index_price, dtype: int64

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.25,random_state= 42)

# %%
sns.regplot(
    x=df_index["interest_rate"],
    y=df_index["index_price"]
)
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(
    x=df_index["interest_rate"],
    y=df_index["unemployment_rate"]
)
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(X_train)
x_test = scaler.fit_transform(X_test)

# %%
x_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression
model  = LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
cvs = cross_val_score(model,X_train,Y_train,scoring = 'neg_mean_squared_error'
                      ,cv = 3)

# %%
cvs
# Out:
# array([-4921.61331265, -7686.87497294, -5135.9962549 ])

# %%
a  = np.mean(cvs)
a
# Out:
# np.float64(-5914.82818016241)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
u= model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse = mean_squared_error(Y_test,y_pred=u)
mae = mean_absolute_error(Y_test,y_pred=u)
mse,mae
# Out:
# (5793.762887712554, 59.935781523235505)
